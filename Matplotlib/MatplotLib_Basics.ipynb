# %%
# %matplotlib inline 
from matplotlib import pyplot as plt #so that we dont get laggy when kernal restart
from matplotlib import style

plt.plot([1,2,3], [2,5,7])
plt.show()

# %%
plt.plot([1,2,3], [2,5,7])
plt.title("Tanishq\'s Data") 
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.show()

# %%
x = [1,5,4]
y = [23,45,89]
x2 = [3,7,3]
y2 = [5,8,9]

#Refer documentation of mat for adv info
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()

# %%
style.use('ggplot')
#Refer matplot's documentation for further info
x = [1,5,4]
y = [23,45,89]
x2 = [3,7,3]
y2 = [5,8,9]

#Refer documentation of mat for adv info
plt.plot(x,y)
plt.plot(x2,y2)
plt.show()

# %%
# style.use('ggplot')
#Refer matplot's documentation for further info
x = [1,5,4]
y = [23,45,89]
x2 = [3,7,3]
y2 = [5,8,9]

#Refer documentation of mat for adv info
plt.plot(x,y, label="first line", linewidth = "4")
plt.plot(x2,y2, label="second line")
plt.legend()
plt.show()

# %%
# style.use('ggplot')
#Refer matplot's documentation for further info
x = [1,5,4]
y = [23,45,89]
x2 = [3,7,3]
y2 = [5,8,9]

#Refer documentation of mat for adv info
plt.plot(x,y, label="first line", linewidth = "4")
plt.scatter(x2,y2, label="second line")
plt.legend()
plt.show()

# %%
#New dataset

plt.style.use('_mpl-gallery')
a = [100,23,25]
b = [25,20,30]
c = [40,26,18]
d = [5, 15,25]

plt.plot(a,b, label="first line", linewidth = "4")
plt.plot(c,d, label="second line")
plt.legend()
plt.show()

# %%
#New dataset
a = [100,23,25]
b = [25,20,30]
c = [40,26,18]
d = [5, 15,25]

plt.hist(c, label="first", linewidth = 3)
plt.plot(c,d, label="second")
plt.legend()
plt.show()
